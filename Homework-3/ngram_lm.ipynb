# %% [markdown]
# Homework 3: n-gram LM
# ----
#
# Due date: October 4th, 2023
#
# Points: 105
#
# Goals:
# - understand the difficulties of counting and probablities in NLP applications
# - work with real world data to build a functioning language model
# - stress test your model (to some extent)
#
# Complete in groups of: __one (individually)__
#
# Allowed python modules:
# - `numpy`, `matplotlib`, and all built-in python libraries (e.g. `math` and `string`)
# - do not use `nltk` or `pandas`
#
# Instructions:
# - Complete outlined problems in this notebook.
# - When you have finished, __clear the kernel__ and __run__ your notebook "fresh" from top to bottom. Ensure that there are __no errors__.
#     - If a problem asks for you to write code that does result in an error (as in, the answer to the problem is an error), leave the code in your notebook but commented out so that running from top to bottom does not result in any errors.
# - Double check that you have completed Task 0.
# - Submit your work on Gradescope.
# - Double check that your submission on Gradescope looks like you believe it should __and__ that all partners are included (for partner work).
#
# 6120 students: complete __all__ problems.
#
# 4120 students: you are not required to complete problems marked "CS 6120 REQUIRED". If you complete these you will not get extra credit. We will not take points off if you attempt these problems and do not succeed.

# %% [markdown]
# Task 0: Name, References, Reflection (5 points)
# ---
#
# Name: Dave Budhram
#
# References
# ---
# List the resources you consulted to complete this homework here. Write one sentence per resource about what it provided to you. If you consulted no references to complete your assignment, write a brief sentence stating that this is the case and why it was the case for you.
#
# (Example)
# - I didn't really use any resources besides class notes. I looked up simple python functions using ChatGPT such as how to do np.random.choice()
# - https://docs.python.org/3/tutorial/datastructures.html
#     - Read about the the basics and syntax for data structures in python.
#
# AI Collaboration
# ---
# Following the *AI Collaboration Policy* in the syllabus, please cite any LLMs that you used here and briefly describe what you used them for. Additionally, provide comments in-line identifying the specific sections that you used LLMs on, if you used them towards the generation of any of your answers.
#
# Reflection
# ----
# Answer the following questions __after__ you complete this assignment (no more than 1 sentence per question required, this section is graded on completion):
#
# 1. Does this work reflect your best effort?
# I believe this work reflects my best effort. I talked about potential solutions with classmates after class to iterate the lecture material. I also went through multiple potential implementations and abstracted my implementation to a level I am satisfied with.
# 2. What was/were the most challenging part(s) of the assignment?
# The most challenging part of the assignment was generating text and figuring out what data structures you should be using sotre information about the tokens you were given.
# 3. If you want feedback, what function(s) or problem(s) would you like feedback on and why?
# I would like feedback on what the best fields for the langauge model would have been.

# %% [markdown]
# Task 1: Berp Data Write-Up (5 points)
# ---
#
# Every time you use a data set in an NLP application (or in any software application), you should be able to answer a set of questions about that data. Answer these now. Default to no more than 1 sentence per question needed. If more explanation is necessary, do give it.

# %% [markdown]
# This is about the __berp__ data set.
#
# 1. Where did you get the data from? https://www1.icsi.berkeley.edu/Speech/berp.html
# 2. How was the data collected (where did the people acquiring the data get it from and how)?
#   - The data was collected at ICSI and it contains almost 9000 utterances with about 1900 words which totals to 7 hours of speech. The audio data was recorded with a Sennheiser close-talking microphone and was sampled at 16 kHz.
# 3. How large is the dataset? (# lines, # tokens)
#   - Number of lines: 6756
#   - Number of tokens: 56696
# 4. What is your data? (i.e. newswire, tweets, books, blogs, etc)
#   - Our data is made up of transcriptions of audio
# 5. Who produced the data? (who were the authors of the text? Your answer might be a specific person or a particular group of people)
#   - Nelson Morgan and the ISCI lead this project.

# %%
from lm_model import read_file, tokenize;
data = read_file('./training_files/./berp-training.txt')
print('Number of lines: ' + str(len(data)))
print('Number of tokens: '+ str(len(tokenize(data, 1, by_char=False))))
print((tokenize(data, 1)))
# Out:
# Number of lines: 6756
# Number of tokens: 56696
# ['<s>', 'l', 'e', 't', "'", 's', ' ', 's', 't', 'a', 'r', 't', ' ', 'o', 'v', 'e', 'r', '</s>', '<s>', 'm', 'y', ' ', 'm', 'o', 't', 'h', 'e', 'r', ' ', 'i', 's', ' ', 'c', 'o', 'm', 'i', 'n', 'g', ' ', 't', 'o', ' ', 'v', 'i', 's', 'i', 't', ' ', 'a', 'n', 'd', ' ', 'i', "'", 'd', ' ', 'l', 'i', 'k', 'e', ' ', 't', 'o', ' ', 't', 'a', 'k', 'e', ' ', 'h', 'e', 'r', ' ', 't', 'o', ' ', 'd', 'i', 'n', 'n', 'e', 'r', '</s>', '<s>', 'n', 'e', 'w', ' ', 'q', 'u', 'e', 'r', 'y', '</s>', '<s>', 'n', 'o', 'w', ' ', 'i', "'", 'm', ' ', 'i', 'n', 't', 'e', 'r', 'e', 's', 't', 'e', 'd', ' ', 'i', 'n', ' ', 's', 'o', 'm', 'e', ' ', 'm', 'i', 'd', 'd', 'l', 'e', ' ', 'e', 'a', 's', 't', 'e', 'r', 'n', ' ', 'f', 'o', 'o', 'd', '</s>', '<s>', 'o', 'h', ' ', 'i', ' ', 'h', 'a', 'v', 'e', ' ', 't', 'o', ' ', 'b', 'r', 'e', 'a', 'k', 'f', 'a', 's', 't', '</s>', '<s>', 'o', 'h', ' ', 'i', ' ', 'i', 'n', 'c', 'r', 'e', 'a', 's', 'e', ' ', 't', 'h', 'e', ' ', 'w', 'a', 'l', 'k', 'i', 'n', 'g', ' ', 'd', 'i', 's', 't', 'a', 'n', 'c', 'e', ' ', 'i', ' ', 'c', 'a', 'n', ' ', 'g', 'o', ' ', 'f', 'i', 'f', 't', 'e', 'e', 'n', ' ', 'm', 'i', 'n', 'u', 't', 'e', 's', ' ', 'f', 'r', 'o', 'm', ' ', 'i', 'c', 's', 'i', '</s>', '<s>', 'o', 'h', ' ', 'i', ' ', 'w', 'o', 'u', 'l', 'd', ' ', 'l', 'i', 'k', 'e', ' ', 't', 'o', ' ', 'h', 'a', 'v', 'e', ' ', 'f', 'r', 'e', 'n', 'c', 'h', ' ', 'f', 'o', 'o', 'd', '</s>', '<s>', 'o', 'k', 'a', 'y', ' ', 'b', 'a', 'c', 'k', ' ', 't', 'o', ' ', 't', 'h', 'e', ' ', 'n', 'o', 'r', 'm', 'a', 'l', ' ', 's', 't', 'u', 'f', 'f', ' ', 'w', 'h', 'a', 't', ' ', 'a', 'b', 'o', 'u', 't', ' ', 'm', 'e', 'x', 'i', 'c', 'a', 'n', '</s>', '<s>', 'o', 'k', 'a', 'y', ' ', 'u', 'h', ' ', 'h', 'o', 'w', ' ', 'a', 'b', 'o', 'u', 't', ' ', 'a', 'm', 'e', 'r', 'i', 'c', 'a', 'n', ' ', 'o', 'r', ' ', 'f', 'r', 'e', 'n', 'c', 'h', ' ', 'o', 'r', ' ', 'u', 'h', ' ', 'e', 'u', 'r', 'o', 'p', 'e', 'a', 'n', ' ', 'f', 'o', 'o', 'd', '</s>', '<s>', 'p', 'r', 'e', 'f', 'e', 'r', ' ', 'g', 'e', 'r', 'm', 'a', 'n', ' ', 'f', 'o', 'o', 'd', '</s>', '<s>', 'p', 'r', 'e', 'f', 'e', 'r', 'a', 'b', 'l', 'y', ' ', 'l', 'e', 's', 's', ' ', 't', 'h', 'a', 'n', ' ', 't', 'e', 'n', ' ', 'd', 'o', 'l', 'l', 'a', 'r', 's', '</s>', '<s>', 's', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g', ' ', 'f', 'a', 't', 't', 'e', 'n', 'i', 'n', 'g', '</s>', '<s>', 's', 't', 'a', 'r', 't', ' ', 'o', 'v', 'e', 'r', '</s>', '<s>', 's', 't', 'a', 'r', 't', ' ', 'o', 'v', 'e', 'r', '</s>', '<s>', 's', 't', 'a', 'r', 't', ' ', 'o', 'v', 'e', 'r', '</s>', '<s>', 't', 'e', 'n', ' ', 'b', 'l', 'o', 'c', 'k', 's', ' ', 'f', 'r', 'o', 'm', ' ', 'i', 'c', 'k', 's', 'e', 'e', '</s>', '<s>', 't', 'h', 'a', 't', "'", 's', ' ', 't', 'o', 'o', ' ', 'f', 'a', 'r', ' ', 'a', 'w', 'a', 'y', '</s>', '<s>', 't', 'h', 'e', ' ', 'm', 'o', 'n', 'e', 'y', ' ', 'd', 'o', 'e', 's', 'n', "'", 't', ' ', 'm', 'a', 't', 't', 'e', 'r', '</s>', '<s>', 't', 'h', 'e', ' ', 'r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't', ' ', 's', 'h', 'o', 'u', 'l', 'd', ' ', 'b', 'e', ' ', 'l', 'e', 's', 's', ' ', 't', 'h', 'a', 'n', ' ', 'f', 'o', 'r', 't', 'y', ' ', 'm', 'i', 'n', 'u', 't', 'e', 's', ' ', 'f', 'r', 'o', 'm', ' ', 'i', 'c', 's', 'i', '</s>', '<s>', 't', 'o', ' ', 's', 'p', 'e', 'n', 'd', ' ', 'n', 'o', ' ', 'm', 'o', 'r', 'e', ' ', 't', 'h', 'a', 'n', ' ', 'f', 'i', 'f', 't', 'y', ' ', 'd', 'o', 'l', 'l', 'a', 'r', 's', '</s>', '<s>', 't', 'u', 'e', 's', 'd', 'a', 'y', 's', '</s>', '<s>', 'u', 'h', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 't', 'h', 'i', 'r', 't', 'y', ' ', 'd', 'o', 'l', 'l', 'a', 'r', 's', '</s>', '<s>', 'u', 'h', ' ', 'i', ' ', 'd', 'o', 'n', "'", 't', ' ', 'm', 'i', 'n', 'd', ' ', 'u', 'h', ' ', 'h', 'a', 'v', 'i', 'n', 'g', ' ', 't', 'o', ' ', 'd', 'r', 'i', 'v', 'e', ' ', 's', 'o', 'm', 'e', 'p', 'l', 'a', 'c', 'e', ' ', 'd', 'o', 'e', 's', 'n', "'", 't', ' ', 'h', 'a', 'v', 'e', ' ', 't', 'o', ' ', 'b', 'e', ' ', 'c', 'l', 'o', 's', 'e', ' ', 't', 'o', ' ', 'i', 'c', 's', 'i', '</s>', '<s> ...

# %% [markdown]
# Task 2: Implement an n-gram Language Model (90 points)
# ----
#
# Implement the `LanguageModel` class as outlined in the provided `lm_starter.py` file. Do not change function signatures (the unit tests that we provide and in the autograder will break).
#
# Your language model:
# - *must* work for both the unigram and bigram cases (5 points are allocated to an experiment involving larger values of `n`)
#     - 6120 students must create a model that works for trigram cases as well
#     - hint: try to implement the bigram case as a generalized "n greater than 1" case
# - should be *token agnostic* (this means that if we give the model text tokenized as single characters, it will function as a character language model and if we give the model text tokenized as "words" (or "traditionally"), then it will function as a language model with those tokens)
# - will use Laplace smoothing
# - will replace all tokens that occur only once with `<UNK>` at train time
#     - do not add `<UNK>` to your vocabulary if no tokens in the training data occur only once!
#
# We have provided:
# - a function to read in files
# - some functions to change a list of strings into tokens
# - the skeleton of the `LanguageModel` class
#
# You need to implement:
# - all functions marked
#
# You may implement:
# - additional functions/methods as helpful to you
#
# As a guideline, including comments, all code required for CS 6120 and some debugging code that can be run with `verbose` parameters, our solution is ~300 lines. (~+120 lines versus the starter code).
#
# Points breakdown marked in code below.

# %%
# rename your lm_starter.py file to lm_model.py and put in the same directory as this file
import lm_model as lm
import numpy as np
import matplotlib.pyplot as plt

# %%
# test the language model (unit tests)
import test_minitrainingprovided as test

# passing all these tests is a good indication that your model
# is correct. They are *not a guarantee*, so make sure to look
# at the tests and the cases that they cover. (we'll be testing
# your model against all of the testing data in addition).

# autograder points in gradescope are assigned SIXTY points
# this is essentially 60 points for correctly implementing your
# underlying model
# there are an additional 10 points manually graded for the correctness
# parts of your sentence generation

# make sure all training files are in a "training_files" directory 
# that is in the same directory as this notebook

unittest = test.TestMiniTraining()
unittest.test_createunigrammodellaplace()
unittest.test_createbigrammodellaplace()
unittest.test_unigramlaplace()
unittest.test_unigramunknownslaplace()
unittest.test_bigramlaplace()
unittest.test_bigramunknownslaplace()
# produces output
unittest.test_generateunigramconcludes()
# produces output
unittest.test_generatebigramconcludes()

unittest.test_onlyunknownsgenerationandscoring()
# Out:
# [['<s>', 'i', '</s>'], ['<s>', '</s>']]
# [['<s>', 'ham', 'i', 'am', '</s>'], ['<s>', 'i', 'am', '</s>']]

# %%
# 5 points
from lm_model import LanguageModel, read_file, tokenize
# instantiate a bigram language model, train it, and generate ten sentences
# make sure your output is nicely formatted!
ngram = 2
training_file_path = "training_files/berp-training.txt"
# YOUR CODE HERE
# optional parameter tells the tokenize function how to tokenize
by_char = False
data = read_file(training_file_path)
train_tokens = tokenize(data, 1, by_char=False)
lm = LanguageModel(ngram)
lm.train(train_tokens)
sentences = lm.generate(10)
for sentence in sentences:
  print(sentence)
# Out:
# ['<s>', 'the', 'cost', 'even', 'more', 'about', 'a', 'meal', '</s>']
# ['<s>', 'ten', 'minutes', '</s>']
# ['<s>', 'start', 'over', '</s>']
# ['<s>', 'do', 'you', 'have', 'indian', 'restaurants', '</s>']
# ['<s>', 'it', 'has', 'to', 'thirty', 'minutes', 'walking', 'distance', "doesn't", 'matter', '</s>']
# ['<s>', 'i', 'want', 'restaurants', '</s>']
# ['<s>', "i'd", 'like', 'to', 'uh', 'tonight', '</s>']
# ['<s>', 'all', 'the', 'name', 'of', 'food', '</s>']
# ['<s>', 'i', 'would', 'like', 'to', 'eat', 'on', 'saturday', '</s>']
# ['<s>', 'i', 'would', 'like', 'to', 'pay', 'five', 'minutes', '</s>']

# %%
# 5 points
import numpy as np
from lm_model import LanguageModel, read_file, tokenize
# evaluate your bigram model on the test data
# score each line in the test data individually, then calculate the average score
# you need not re-train your model
test_path = "testing_files/berp-test.txt"
test_data = read_file(test_path)
test_tokens = tokenize(test_data, 1, by_char=False)

sentences = []
sentence = []
for char in test_tokens:
  sentence.append(char)
  if char == '</s>':
    sentences.append(sentence)
    sentence = []
# YOUR CODE HERE
scores = []
for sentence in sentences:
  scores.append(lm.score(sentence))

print(scores)

# # Print out the mean score and standard deviation
# # for words-as-tokens, these values should be
# # ~4.9 * 10^-5 and 0.000285
# Calculate mean
mean = np.mean(scores)

# Calculate standard deviation
std_dev = np.std(scores)

print("Mean:", mean)
print("Standard Deviation:", std_dev)
# Out:
# [4.267489182007139e-09, 1.058678488519422e-07, 5.149694499711512e-16, 9.840088702332027e-14, 9.87568778397694e-19, 1.1208706642045032e-12, 4.145917865353985e-12, 4.313804428980062e-23, 4.202541078255796e-16, 0.00038481991404015455, 2.727786594737561e-09, 1.4218481175108608e-10, 8.532921994870666e-14, 2.2528894489178235e-05, 1.982948372716848e-11, 1.0764878634720196e-05, 2.7654019059149935e-05, 6.309448156557719e-06, 2.5274579443101176e-12, 1.421449214828301e-20, 3.2819995486938984e-33, 2.7476918576083813e-31, 6.958216679056783e-19, 3.2099162925805784e-15, 5.515773209462602e-16, 8.326222899740294e-10, 8.038320972634002e-06, 1.7653376266799547e-09, 2.0376088145326543e-20, 7.352888713479303e-12, 4.458883717538469e-09, 5.077099899888246e-15, 2.9084487149189727e-13, 6.561898428242177e-11, 5.30959228972205e-17, 4.342685678148236e-15, 1.0883585916963686e-07, 7.021749141253345e-08, 1.5350997079911911e-13, 5.902491866980707e-10, 4.713630863921775e-13, 8.744760733311371e-12, 3.5867232906971456e-11, 1.5052074797419106e-16, 1.1354133215415843e-13, 2.4637591956814967e-15, 1.2564160617580698e-10, 6.188226148610612e-10, 9.449758949630655e-17, 5.14325508596936e-19, 4.8719261776970465e-21, 6.27557866161159e-14, 9.65512856741093e-06, 0.0003092529736505652, 0.0003092529736505652, 2.594572438108474e-12, 6.566925972522208e-12, 3.057584177724582e-06, 5.618082947701129e-08, 1.0394259865530474e-13, 0.0025322812585780634, 3.294475851534205e-14, 1.5494079633584878e-15, 1.086567497912845e-11, 3.2104676064121284e-21, 1.0600760171691269e-15, 2.074486317471346e-06, 4.0110458855627215e-05, 1.2505977721416297e-05, 2.4713831758757442e-18, 5.779368787198792e-16, 2.7141388941617894e-19, 4.13002024083311e-10, 7.463211350842725e-11, 1.6553126351238575e-24, 3.7714859025159354e-12, 1.395933109399019e-08, 4.9377678089997956e-12, 1.7830393267928877e-10, 8.85588899936649e-17, 1.2711834088994795e-09, 1.5097539280577715e-07, 8.401631596856109e-07, 1.8677744945660814e-10, 3.529808964797041e-25, 1.0757013596601142e-10, 3.4373731332538383e-56, 3.075741005382426e-19, 0.001276917238028014, 8.388761864242552e-17, 5.978543491404001e-11, 3.942801602873458e-11, 5.453895616948343e-06, 6.101160829249821e-13, 1.13431358863377e-12, 1.3988323206447078e-12, 4.0491224423204124e-08, 4.2602352190427383e-14, 1.4671181128182855e-15, 1.8280876838934466e-10]
# Mean: 4.9620823627262653e-05
# Standard Deviation: 0.000285298086084196

# %%
# 5 points
import time
# see if you can train your model on the data you found for your first homework
from lm_model import LanguageModel, read_file, tokenize;
FILE = './classroom_of_the_elite_y2_v6.txt'
data = []
with open(FILE, 'r') as file:
  for line in file:
    if 'RoyalMTL' not in line and not line.strip().isnumeric() :
      data.extend(line.strip())
data = read_file(FILE)
tokens = tokenize(data, 1, by_char=False)

# what is the maximum value of n <= 10 that you can train a model *in your programming environment* in a reasonable amount of time? (less than 3 - 5 minutes)
n = 10
lm = LanguageModel(n)
start = time.time_ns()
lm.train(tokens)
end = time.time_ns()
print(str((end - start)/ 1000000000) + ': seconds')
# generate three sentences with this model
sents = lm.generate(3)
for sentence in sents:
  print(sentence)
# Out:
# 0.255215: seconds
# ['<s>', '<UNK>', '</s>', '<s>', 'It', 'was', 'the', 'third', 'round', 'of', 'our', 'competition,', 'and', 'it', 'closed', 'for', 'entries', 'at', '<UNK>', 'p.m.', '</s>']
# ['<s>', '<UNK>', '</s>', '<s>', '“Basically,', 'Sakayanagi,', 'it’s', 'exactly', 'what', 'you’re', 'trying', 'to', 'do.', 'You’re', '</s>']
# ['<s>', '“What?', 'Is', 'the', '20th', 'is', 'the', 'same', 'birthday', '<UNK>', '<UNK>', 'Kei', 'comes', 'looking', 'up', 'at', 'me,', 'somewhat', '<UNK>', '</s>']

# %% [markdown]
# CS 6120 REQUIRED
# ----
# Implement the corresponding function and evaluate the perplexity of your model on the first 20 lines in the test data for values of `n` from 1 to 3. Perplexity should be individually calculated for each line.

# %%
test_path = "testing_files/berp-test.txt"
test_data = lm.read_file(test_path)

for ngram in range(1, 4):
    print("********")
    print("Ngram model:", ngram)
    # YOUR CODE HERE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/davebudhram/Documents/Northeastern/CS4120/Homework-3/ngram_lm.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/Users/davebudhram/Documents/Northeastern/CS4120/Homework-3/ngram_lm.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> test_path = "testing_files/berp-test.txt"
# ----> <a href='vscode-notebook-cell:/Users/davebudhram/Documents/Northeastern/CS4120/Homework-3/ngram_lm.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> test_data = lm.read_file(test_path)
#       <a href='vscode-notebook-cell:/Users/davebudhram/Documents/Northeastern/CS4120/Homework-3/ngram_lm.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> for ngram in range(1, 4):
#       <a href='vscode-notebook-cell:/Users/davebudhram/Documents/Northeastern/CS4120/Homework-3/ngram_lm.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     print("********")
#
# AttributeError: 'LanguageModel' object has no attribute 'read_file'

# %% [markdown]
# 1. What are the common attributes of the test sentences that cause very high perplexity? __YOUR ANSWER HERE__

# %% [markdown]
# 5 points in this assignment are reserved for overall style (both for writing and for code submitted). All work submitted should be clear, easily interpretable, and checked for spelling, etc. (Re-read what you write and make sure it makes sense). Course staff are always happy to give grammatical help (but we won't pre-grade the content of your answers).
